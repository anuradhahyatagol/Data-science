# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Train = pd.read_csv('SalaryData_Train.csv',encoding='ISO-8859-1')

# %%
Train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
Train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
Test= pd.read_csv('SalaryData_Test.csv',encoding='ISO-8859-1')

# %%
Test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
Test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
string_columns = ["workclass","education","educationno","maritalstatus","occupation","relationship","race","sex","capitalgain","capitalloss","hoursperweek","native","Salary"]

# %%
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import StandardScaler
number = LabelEncoder()
for i in string_columns:
    Train[i]=number.fit_transform(Train[i])
    Test[i]=number.fit_transform(Test[i])

# %%
Train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           12              4           0
# 1       50          4          9           12              2           3
# 2       38          2         11            8              0           5
# 3       53          2          1            6              2           5
# 4       28          2          9           12              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           11              2          12
# 30157   40          2         11            8              2           6
# 30158   58          2         11            8              6           0
# 30159   22          2         11            8              4           0
# 30160   52          3         11            8              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
Test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            6              4           6
# 1       38          2         11            8              2           4
# 2       28          1          7           11              2          10
# 3       44          2         15            9              2           6
# 4       34          2          0            5              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           12              4           9
# 15056   39          2          9           12              0           9
# 15057   38          2          9           12              2           9
# 15058   44          2          9           12              0           0
# 15059   35          3          9           12              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
colnames = Train.columns
colnames
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
x_train = Train[colnames[0:14]].values
y_train = Train[colnames[-1]].values
x_test = Test[colnames[0:14]].values
y_test = Test[colnames[-1]].values

# %%
x_train
# Out:
# array([[39,  5,  9, ..., 39, 37,  0],
#        [50,  4,  9, ..., 12, 37,  0],
#        [38,  2, 11, ..., 39, 37,  0],
#        ...,
#        [58,  2, 11, ..., 39, 37,  0],
#        [22,  2, 11, ..., 19, 37,  0],
#        [52,  3, 11, ..., 39, 37,  1]], dtype=int64)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
x_test
# Out:
# array([[25,  2,  1, ..., 39, 37,  0],
#        [38,  2, 11, ..., 49, 37,  0],
#        [28,  1,  7, ..., 39, 37,  1],
#        ...,
#        [38,  2,  9, ..., 49, 37,  0],
#        [44,  2,  9, ..., 39, 37,  0],
#        [35,  3,  9, ..., 59, 37,  1]], dtype=int64)

# %%
y_test
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %% [markdown]
# # Naive Bayes Model

# %%
from sklearn.naive_bayes import MultinomialNB as MB

# %%
#MultinomialNB
M_model = MB()
train_pred_multi = M_model.fit(x_train,y_train).predict(x_train)
test_pred_multi = M_model.fit(x_train,y_train).predict(x_test)

# %%
train_acc_multi = np.mean(train_pred_multi==y_train)
train_acc_multi
# Out:
# 0.7797486820728756

# %%
test_acc_multi = np.mean(test_pred_multi==y_test)
test_acc_multi
# Out:
# 0.7817397078353253

# %%
#GaussianNB 
from sklearn.naive_bayes import GaussianNB
G_model = GB()
train_pred_gau= G_model.fit(x_train,y_train).predict(x_train)
test_pred_gau = G_model.fit(x_train,y_train).predict(x_test)

# %%
train_acc_gau = np.mean(train_pred_gau==y_train)
train_acc_gau
# Out:
# 1.0

# %%
test_acc_gau = np.mean(test_pred_gau==y_test)
test_acc_gau
# Out:
# 1.0

# %%
sns.countplot(x='Salary',data=Train)
plt.xlabel('Salary')
plt.ylabel('count')
plt.show()

# %%
sns.countplot(x='Salary',data=Test)
plt.xlabel('Salary')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(12,5))
Train.workclass.value_counts().plot.bar(color='yellow');

# %%
plt.figure(figsize=(12,5))
Test.workclass.value_counts().plot.bar(color='yellow');

# %% [markdown]
# for private workclass frequency is high and without-pay workclass has less frequency.

# %%
plt.figure(figsize=(12,5))
Train.education.value_counts().plot.bar(color='pink');

# %%
plt.figure(figsize=(12,5))
Test.education.value_counts().plot.bar(color='pink');

# %% [markdown]
# for education HS-grad is has high frequency. and  preschool as less frequency.

# %%
plt.figure(figsize=(12,5))
Train.educationno.value_counts().plot.bar(color='red');

# %%
plt.figure(figsize=(12,5))
Test.educationno.value_counts().plot.bar(color='red');

# %% [markdown]
# for 9 education no the frequency is high.
# for 1 education no the frequency is low.

# %%
plt.figure(figsize=(12,5))
Train.occupation.value_counts().plot.bar(color='orange');

# %%
plt.figure(figsize=(12,5))
Test.occupation.value_counts().plot.bar(color='orange')
# Out:
# <Axes: xlabel='occupation'>

# %% [markdown]
# for the Exes-managerial occuption the frequency is vary high.

# %%
plt.figure(figsize=(12,5))
Train.hoursperweek.value_counts().plot.bar(color='blue');

# %%
plt.figure(figsize=(12,5))
Test.hoursperweek.value_counts().plot.bar(color='blue');

# %% [markdown]
# some data has the vary less frequncy

# %%
plt.figure(figsize=(12,5))
Train.Salary.value_counts().plot.bar(color='brown');

# %%
plt.figure(figsize=(12,5))
Test.Salary.value_counts().plot.bar(color='brown');

# %% [markdown]
# for greater than and eqal to 50k salary the frequancy is vary high and less for less then 50k salary
